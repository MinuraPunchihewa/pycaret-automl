# %%
import pandas as pd
from pycaret.regression import setup, compare_models, evaluate_model, predict_model, finalize_model, \
     save_model, load_model, create_docker

# %%
# path to data file
path = '../data/wine-quality.csv'

# %%
# read data
df = pd.read_csv(path)

# %%
# view sample of data
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# setup the dataset
# must be called before executing any other function
# can configure many types of transformation operations
# by default Missing Value Imputation, One-Hot Encoding and Train-Test Split operations will be performed
# press enter to continue
grid = setup(data=df, target=df.columns[-1])
# Out:
# <style type="text/css">
# #T_a5974_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a5974">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5974_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a5974_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5974_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5974_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a5974_row0_col1" class="data row0 col1" >3161</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5974_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a5974_row1_col1" class="data row1 col1" >quality</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5974_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_a5974_row2_col1" class="data row2 col1" >(1599, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5974_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_a5974_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a5974_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_a5974_row4_col1" class="data row4 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a5974_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_a5974_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a5974_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_a5974_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a5974_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_a5974_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a5974_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_a5974_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a5974_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_a5974_row9_col1" class="data row9 col1" >(1119, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a5974_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_a5974_row10_col1" class="data row10 col1" >(480, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a5974_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_a5974_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a5974_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_a5974_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a5974_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_a5974_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a5974_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_a5974_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a5974_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_a5974_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a5974_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_a5974_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a5974_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_a5974_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a5974_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_a5974_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a5974_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_a5974_row19_col1" class="data row19 col1" >a487</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a5974_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_a5974_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a5974_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_a5974_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a5974_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_a5974_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a5974_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_a5974_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_a5974_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_a5974_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_a5974_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_a5974_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_a5974_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_a5974_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_a5974_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_a5974_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_a5974_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_a5974_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_a5974_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_a5974_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a5974_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_a5974_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_a5974_row30_col1" class

# %%
# train and compare all supported models
# uses cross-validation
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_e1859 th {
#   text-align: left;
# }
# #T_e1859_row0_col0, #T_e1859_row1_col0, #T_e1859_row1_col1, #T_e1859_row1_col2, #T_e1859_row1_col3, #T_e1859_row1_col4, #T_e1859_row1_col5, #T_e1859_row1_col6, #T_e1859_row2_col0, #T_e1859_row2_col1, #T_e1859_row2_col2, #T_e1859_row2_col3, #T_e1859_row2_col4, #T_e1859_row2_col5, #T_e1859_row2_col6, #T_e1859_row3_col0, #T_e1859_row3_col1, #T_e1859_row3_col2, #T_e1859_row3_col3, #T_e1859_row3_col4, #T_e1859_row3_col5, #T_e1859_row3_col6, #T_e1859_row4_col0, #T_e1859_row4_col1, #T_e1859_row4_col2, #T_e1859_row4_col3, #T_e1859_row4_col4, #T_e1859_row4_col5, #T_e1859_row4_col6, #T_e1859_row5_col0, #T_e1859_row5_col1, #T_e1859_row5_col2, #T_e1859_row5_col3, #T_e1859_row5_col4, #T_e1859_row5_col5, #T_e1859_row5_col6, #T_e1859_row6_col0, #T_e1859_row6_col1, #T_e1859_row6_col2, #T_e1859_row6_col3, #T_e1859_row6_col4, #T_e1859_row6_col5, #T_e1859_row6_col6, #T_e1859_row7_col0, #T_e1859_row7_col1, #T_e1859_row7_col2, #T_e1859_row7_col3, #T_e1859_row7_col4, #T_e1859_row7_col5, #T_e1859_row7_col6, #T_e1859_row8_col0, #T_e1859_row8_col1, #T_e1859_row8_col2, #T_e1859_row8_col3, #T_e1859_row8_col4, #T_e1859_row8_col5, #T_e1859_row8_col6, #T_e1859_row9_col0, #T_e1859_row9_col1, #T_e1859_row9_col2, #T_e1859_row9_col3, #T_e1859_row9_col4, #T_e1859_row9_col5, #T_e1859_row9_col6, #T_e1859_row10_col0, #T_e1859_row10_col1, #T_e1859_row10_col2, #T_e1859_row10_col3, #T_e1859_row10_col4, #T_e1859_row10_col5, #T_e1859_row10_col6, #T_e1859_row11_col0, #T_e1859_row11_col1, #T_e1859_row11_col2, #T_e1859_row11_col3, #T_e1859_row11_col4, #T_e1859_row11_col5, #T_e1859_row11_col6, #T_e1859_row12_col0, #T_e1859_row12_col1, #T_e1859_row12_col2, #T_e1859_row12_col3, #T_e1859_row12_col4, #T_e1859_row12_col5, #T_e1859_row12_col6, #T_e1859_row13_col0, #T_e1859_row13_col1, #T_e1859_row13_col2, #T_e1859_row13_col3, #T_e1859_row13_col4, #T_e1859_row13_col5, #T_e1859_row13_col6, #T_e1859_row14_col0, #T_e1859_row14_col1, #T_e1859_row14_col2, #T_e1859_row14_col3, #T_e1859_row14_col4, #T_e1859_row14_col5, #T_e1859_row14_col6, #T_e1859_row15_col0, #T_e1859_row15_col1, #T_e1859_row15_col2, #T_e1859_row15_col3, #T_e1859_row15_col4, #T_e1859_row15_col5, #T_e1859_row15_col6, #T_e1859_row16_col0, #T_e1859_row16_col1, #T_e1859_row16_col2, #T_e1859_row16_col3, #T_e1859_row16_col4, #T_e1859_row16_col5, #T_e1859_row16_col6, #T_e1859_row17_col0, #T_e1859_row17_col1, #T_e1859_row17_col2, #T_e1859_row17_col3, #T_e1859_row17_col4, #T_e1859_row17_col5, #T_e1859_row17_col6 {
#   text-align: left;
# }
# #T_e1859_row0_col1, #T_e1859_row0_col2, #T_e1859_row0_col3, #T_e1859_row0_col4, #T_e1859_row0_col5, #T_e1859_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e1859_row0_col7, #T_e1859_row1_col7, #T_e1859_row2_col7, #T_e1859_row3_col7, #T_e1859_row4_col7, #T_e1859_row5_col7, #T_e1859_row6_col7, #T_e1859_row7_col7, #T_e1859_row8_col7, #T_e1859_row9_col7, #T_e1859_row10_col7, #T_e1859_row11_col7, #T_e1859_row12_col7, #T_e1859_row13_col7, #T_e1859_row14_col7, #T_e1859_row16_col7, #T_e1859_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e1859_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e1859">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1859_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e1859_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e1859_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e1859_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e1859_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e1859_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e1859_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e1859_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1859_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_e1859_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_e1859_row0_col1" class="data row0 col1" >0.4082</td>
#       <td id="T_e1859_row0_col2" class="data row0 col2" >0.3602</td>
#       <td id="T_e1859_row0_col3" class="data row0 col3" >0.5973</td>
#       <td id="T_e1859_row0_col4" class="data row0 col4" >0.4460</td>
#       <td id="T_e1859_row0_col5" class="data row0 col5" >0.0933</td>
#       <td id="T_e1859_row0_col6" class="data row0 col6" >0.0761</td>
#       <td id="T_e1859_row0_col7" class="data row0 col7" >0.1530</td>
#     </tr>
#     <tr>
#       <th id="T_e1859_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_e1859_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_e1859_row1_col1" class="data row1 col1" >0.4435</td>
#       <td id="T_e1859_row1_col2" class="data row1 col2" >0.3781</td>
#       <td id="T_e1859_row1_col3" class="data row1 col3" >0.6119</td>
#       <td id="T_e1859_row1_col4" class="data row1 col4" >0.4188</td>
#       <td id="T_e1859_row1_col5" class="data row1 col5" >0.0954</td>
#       <td id="T_e1859_row1_col6" class="data row1 col6" >0.0824</td>
#       <td id="T_e1859_row1_col7" class="data row1 col7" >0.1980</td>
#     </tr>
#     <tr>
#       <th id="T_e1859_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_e1859_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_e1859_row2_col1" class="data row2 col1" >0.4858</td>
#       <td id="T_e1859_row2_col2" class="data row2 col2" >0.4065</td>
#       <td id="T_e1859_row2_col3" class="data row2 col3" >0.6347</td>
#       <td id="T_e1859_row2_col4" class="data row2 col4" >0.3746</td>
#       <td id="T_e1859_row2_col5" class="data row2 col5" >0.0980</td>
#       <td id="T_e1859_row2_col6" class="data row2 col6" >0.0892</td>
#       <td id="T_e1859_row2_col7" class="data row2 col7" >0.0670</td>
#     </tr>
#     <tr>
#       <th id="T_e1859_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_e1859_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e1859_row3_col1" class="data row3 col1" >0.4645</td>
#       <td id="T_e1859_row3_col2" class="data row3 col2" >0.4105</td>
#       <td id="T_e1859_row3_col3" class="data row3 col3" >0.6373</td>
#       <td id="T_e1859_row3_col4" class="data row3 col4" >0.3670</td>
#       <td id="T_e1859_row3_col5" class="data row3 col5" >0.0989</td>
#       <td id="T_e1859_row3_col6" class="data row3 col6" >0.0860</td>
#       <td id="T_e1859_row3_col7" class="data row3 col7" >0.1320</td>
#     </tr>
#     <tr>
#       <th id="T_e1859_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_e1859_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_e1859_row4_col1" class="data row4 col1" >0.5163</td>
#       <td id="T_e1859_row4_col2" class="data row4 col2" >0.4196</td>
#       <td id="T_e1859_row4_col3" class="data row4 col3" >0.6462</td>
#       <td id="T_e1859_row4_col4" class="data row4 col4" >0.3557</td>
#       <td id="T_e1859_row4_col5" class="data row4 col5" >0.1002</td>
#       <td id="T_e1859_row4_col6" class="data row4 col6" >0.0953</td>
#       <td id="T_e1859_row4_col7" class="data row4 col7" >0.0510</td>
#     </tr>
#     <tr>
#       <th id="T_e1859_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_e1859_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_e1859_row5_col1" class="data row5 col1" >0.5054</td>
#       <td id="T_e1859_row5_col2" class="data row5 col2" >0.4342</td>
#       <td id="T_e1859_row5_col3" class="data row5 col3" >0.6573</td>
#       <td id="T_e1859_row5_col4" class="data row5 col4" >0.3311</td>
#       <td id="T_e1859_row5_col5" class="data row5 col5" >0.1015</td>
#       <td id="T_e1859_row5_col6" class="data row5 col6" >0.0929</td>
#       <td id="T_e1859_row5_col7" class="data row5 col7" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_e1859_level0_row6"

# %%
# report the best model
print(best_model)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=-1, oob_score=False,
#                     random_state=3161, verbose=0, warm_start=False)

# %%
# evaluate the model using a number of different plots
# click on the different plot types to exlpore
# some plots may not work depending on the data and the model
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
# make predictions on new data
# data should be a DataFrame without label
# predict_model(best_model, new_data)

# %%
# finalize model
# trains the model on the entire dataset including the hold-out set
# does not change any parameter of the model
final_model = finalize_model(best_model)

# %%
# save model as pickle file
save_model(final_model, 'regression_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='quality',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy...
#                   ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0,
#                                       criterion='mse', max_depth=None,
#                                       max_features='auto', max_leaf_nodes=None,
#                                       max_samples=None,
#                                       min_impurity_decrease=0.0,
#                                       min_impurity_split=None,
#                                       min_samples_leaf=1, min_samples_split=2,
#                                       min_weight_fraction_leaf=0.0,
#                                       n_estimators=100, n_jobs=-1,
#                                       oob_score=False, random_state=3161,
#                                       verbose=0, warm_start=False)]],
#           verbose=False),
#  'regression_model.pkl')

# %%
# load saved model for use
model = load_model('regression_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
# create Dockerfile for model
# also creates a requirements.txt file for dependencies
create_docker('regression_model')
# Out:
# Writing requirements.txt
# Writing Dockerfile
# Dockerfile and requirements.txt successfully created.
# To build image you have to run --> !docker image build -f "Dockerfile" -t IMAGE_NAME:IMAGE_TAG .
